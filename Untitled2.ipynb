# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   )

train_generator = train_datagen.flow_from_directory(
    directory = 'drive/MyDrive/Cat vs Dogs/PetImages',
    target_size = (150,150),
    batch_size = 251,
    class_mode = 'binary'
)
# Out:
# Found 25054 images belonging to 2 classes.

# %%
from tensorflow.keras.optimizers import RMSprop

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation = 'relu', input_shape = (150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

model.compile( loss = 'binary_crossentropy',
             optimizer = RMSprop(learning_rate = 0.001),
             metrics = ['accuracy']
             )

# %%
history = model.fit(
    train_generator,
    steps_per_epoch = 100,
    epochs = 15
)
# Out:
# Epoch 1/15
#  18/100 [====>.........................] - ETA: 15:47 - loss: 0.9458 - accuracy: 0.4960
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 282
#   " Skipping tag %s" % (size, len(data), tag)
# ...

# %%
from keras.preprocessing import image

img=image.load_img('drive/MyDrive/Cat vs Dogs/Test_img/dog (1).jpg', target_size=(150, 150))
x=image.img_to_array(img)
x /= 255
x=np.expand_dims(x, axis=0)
images = np.vstack([x])

print(model.predict(images))

classes = model.predict(images)

if classes >0.5:
    print(" is a dog")
else:
    print(" is a cat")

img
# Out:
# [[0.91075367]]
#  is a dog
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F8E28F76C10>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
img=image.load_img('drive/MyDrive/Cat vs Dogs/Test_img/cat.jpg', target_size=(150, 150))
x=image.img_to_array(img)
x /= 255
x=np.expand_dims(x, axis=0)
images = np.vstack([x])

print(model.predict(images))

classes = model.predict(images)

if classes >0.5:
    print(" is a dog")
else:
    print(" is a cat")

img
# Out:
# [[0.00238809]]
#  is a cat
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F8E20E87910>

# %%
img=image.load_img('test.jpg', target_size=(150, 150))
x=image.img_to_array(img)
x /= 255
x=np.expand_dims(x, axis=0)
images = np.vstack([x])

print(model.predict(images))

classes = model.predict(images)

if classes >0.5:
    print(" is a dog")
else:
    print(" is a cat")

img
# Out:
# [[2.9781966e-06]]
#  is a cat
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F8E28E60610>

# %%
img=image.load_img('test1.png', target_size=(150, 150))
x=image.img_to_array(img)
x /= 255
x=np.expand_dims(x, axis=0)
images = np.vstack([x])

print(model.predict(images))

classes = model.predict(images)

if classes >0.5:
    print(" is a dog")
else:
    print(" is a cat")

img
# Out:
# [[0.43439183]]
#  is a cat
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F8E28FE4DD0>

# %%
path = '/content/drive/MyDrive/Cat vs Dogs/Cat_vs_dogs.h5'

model.save(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-201ca491642a> in <module>()
#       1 path = '/content/drive/MyDrive/Cat vs Dogs/Cat_vs_dogs.h5'
#       2
# ----> 3 model.save(path)
#
# NameError: name 'model' is not defined

# %%
def model_prediction(test_image_path):
    img=image.load_img(test_image_path, target_size=(150, 150))
    x=image.img_to_array(img)
    x /= 255
    x=np.expand_dims(x, axis=0)
    images = np.vstack([x])

    print(model.predict(images))

    classes = model.predict(images)

    if classes >0.5:
        return (" is a dog")
    else:
        return(" is a cat")

# %%
print(model_prediction('test.jpg'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fce6b258c1b8> in <module>()
# ----> 1 print(model_prediction('test.jpg'))
#
# <ipython-input-2-fe11c1295d1f> in model_prediction(test_image_path)
#       1 def model_prediction(test_image_path):
# ----> 2     img=image.load_img(test_image_path, target_size=(150, 150))
#       3     x=image.img_to_array(img)
#       4     x /= 255
#       5     x=np.expand_dims(x, axis=0)
#
# NameError: name 'image' is not defined
